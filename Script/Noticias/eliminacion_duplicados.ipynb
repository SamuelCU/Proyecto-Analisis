# %%
import pandas as pd

# %%
file = pd.read_csv("newsJoin.csv")
file
# Out:
# C:\Users\samcu\AppData\Local\Temp\ipykernel_8036\2717003019.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv("newsJoin.csv")
#         Unnamed:0                                              title  \
# 0             0.0  House Republicans Fret About Winning Their Hea...
# 1             1.0  Rift Between Officers and Residents as Killing...
# 2             2.0  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3             3.0  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4             4.0  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...                                                ...
# 182758        NaN        Ratcliffe wants 'national stadium in north'
# 182759        NaN            Stokes bowls in nets before fourth Test
# 182760        NaN  Gauff 'fuelled' by umpire row to reach Dubai q...
# 182761        NaN  Verstappen makes ominous start to pre-season t...
# ...

# %%
file_none = file.drop_duplicates()

# %%
file
# Out:
#         Unnamed:0                                              title  \
# 0             0.0  House Republicans Fret About Winning Their Hea...
# 1             1.0  Rift Between Officers and Residents as Killing...
# 2             2.0  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3             3.0  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4             4.0  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...                                                ...
# 182758        NaN        Ratcliffe wants 'national stadium in north'
# 182759        NaN            Stokes bowls in nets before fourth Test
# 182760        NaN  Gauff 'fuelled' by umpire row to reach Dubai q...
# 182761        NaN  Verstappen makes ominous start to pre-season t...
# 182762        NaN  Osimhen scores on return as Napoli hold Barcelona
#
#            publication                         author        date    year  \
# ...

# %%
file_none.isnull().sum()
# Out:
# Unnamed:0      28555
# title             15
# publication    38992
# author         28556
# date           38992
# year           38992
# month          38992
# content        28579
# dtype: int64

# %%
umbral = len(file.columns)-1
file_none = file.dropna(thresh=umbral)

file_none
# Out:
#         Unnamed:0                                              title  \
# 0             0.0  House Republicans Fret About Winning Their Hea...
# 1             1.0  Rift Between Officers and Residents as Killing...
# 2             2.0  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3             3.0  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4             4.0  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...                                                ...
# 142565   146028.0  An eavesdropping Uber driver saved his 16-year...
# 142566   146029.0  Plane carrying six people returning from a Cav...
# 142567   146030.0  After helping a fraction of homeowners expecte...
# 142568   146031.0  Yes, this is real: Michigan just banned bannin...
# 142569   146032.0  What happened in Washington state after voters...
#
#             publication                         author        date    year  \
# ...

# %%
file_none.isnull().sum()
# Out:
# Unnamed:0       0
# title          15
# publication     0
# author          1
# date            0
# year            0
# month           0
# content        24
# dtype: int64

# %%
file_none = file_none.dropna(subset=['title'])
file_none.isnull().sum()
# Out:
# Unnamed:0       0
# title           0
# publication     0
# author          1
# date            0
# year            0
# month           0
# content        24
# dtype: int64

# %%
file_none
# Out:
#         Unnamed:0                                              title  \
# 0             0.0  House Republicans Fret About Winning Their Hea...
# 1             1.0  Rift Between Officers and Residents as Killing...
# 2             2.0  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3             3.0  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4             4.0  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...                                                ...
# 142565   146028.0  An eavesdropping Uber driver saved his 16-year...
# 142566   146029.0  Plane carrying six people returning from a Cav...
# 142567   146030.0  After helping a fraction of homeowners expecte...
# 142568   146031.0  Yes, this is real: Michigan just banned bannin...
# 142569   146032.0  What happened in Washington state after voters...
#
#             publication                         author        date    year  \
# ...

# %%
file_none.to_csv('newsFinal.csv', index=False)

# %%
from pymongo import MongoClient
import pandas as pd

#Conexion e importacion o subir de datos a MongoDB Atlas
cadena_conec="mongodb+srv://monicajana1804:moni123@clusteranalisis.cjkeykr.mongodb.net/"
client=MongoClient(cadena_conec)
db=client['DataLake']
collection=db['noticias']
# Leer el archivo CSV en un DataFrame
df = pd.read_csv('newsFinal.csv')
# Convertir el DataFrame a una lista de diccionarios
diccionario = df.to_dict(orient='records')
#Subimos 
collection.insert_many(diccionario)
client.close()
# Out:
# C:\Users\samcu\AppData\Local\Temp\ipykernel_8036\2319685497.py:10: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('newsFinal.csv')
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[22], line 14
#      12 diccionario = df.to_dict(orient='records')
#      13 #Subimos
# ---> 14 collection.insert_many(diccionario)
#      15 client.close()
#
# File c:\Users\samcu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# ...
