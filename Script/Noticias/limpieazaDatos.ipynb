# %%
import pandas as pd

# %%
file1 = pd.read_csv("articles1.csv", index_col="id")
file1
# Out:
#        Unnamed: 0                                              title  \
# id
# 17283           0  House Republicans Fret About Winning Their Hea...
# 17284           1  Rift Between Officers and Residents as Killing...
# 17285           2  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 17286           3  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 17287           4  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...                                                ...
# 73465       53287   Rex Tillerson Says Climate Change Is Real, but …
# 73466       53288  The Biggest Intelligence Questions Raised by t...
# 73467       53289  Trump Announces Plan That Does Little to Resol...
# 73468       53290    Dozens of For-Profit Colleges Could Soon Close
# 73469       53291                       The Milky Way’s Stolen Stars
#
#           publication                         author        date    year  \
# id
# ...

# %%
file2 = pd.read_csv("articles2.csv")
file2
# Out:
#        Unnamed: 0      id                                              title  \
# 0           53293   73471  Patriots Day Is Best When It Digs Past the Her...
# 1           53294   73472  A Break in the Search for the Origin of Comple...
# 2           53295   73474         Obama’s Ingenious Mention of Atticus Finch
# 3           53296   73475         Donald Trump Meets, and Assails, the Press
# 4           53297   73476               Trump: ’I Think’ Hacking Was Russian
# ...           ...     ...                                                ...
# 49994      103453  151902  If Baltimore is serious about police reform, g...
# 49995      103454  151903  The transition from summer to fall feels like ...
# 49996      103455  151904  Colombia: Farc’s female fighters, then and now...
# 49997      103456  151905                      Why I’m optimistic about 2017
# 49998      103457  151906  Prayer and pain: why gay conversion therapy is...
#
# ...

# %%
file3 = pd.read_csv("articles3.csv")
file3
# Out:
#        Unnamed: 0      id                                              title  \
# 0          103459  151908  Alton Sterling’s son: ’Everyone needs to prote...
# 1          103460  151909  Shakespeare’s first four folios sell at auctio...
# 2          103461  151910  My grandmother’s death saved me from a life of...
# 3          103462  151911  I feared my life lacked meaning. Cancer pushed...
# 4          103463  151912  Texas man serving life sentence innocent of do...
# ...           ...     ...                                                ...
# 42566      146028  218078  An eavesdropping Uber driver saved his 16-year...
# 42567      146029  218079  Plane carrying six people returning from a Cav...
# 42568      146030  218080  After helping a fraction of homeowners expecte...
# 42569      146031  218081  Yes, this is real: Michigan just banned bannin...
# 42570      146032  218082  What happened in Washington state after voters...
#
# ...

# %%
file4 = pd.read_csv("articles_data.csv", header=0)
file4
# Out:
#        Unnamed: 0           source_id         source_name  \
# 0               0             reuters             Reuters
# 1               1     the-irish-times     The Irish Times
# 2               2     the-irish-times     The Irish Times
# 3               3  al-jazeera-english  Al Jazeera English
# 4               4            bbc-news            BBC News
# ...           ...                 ...                 ...
# 10432       10432            abc-news            ABC News
# 10433       10433             reuters             Reuters
# 10434       10434                 cnn                 CNN
# 10435       10435            cbs-news            CBS News
# 10436       10436            cbs-news            CBS News
#
#                        author  \
# 0           Reuters Editorial
# 1          Eoin Burke-Kennedy
# 2           Deirdre McQuillan
# 3                  Al Jazeera
# 4                    BBC News
# ...                       ...
# 10432    The Associated Press
# ...

# %%
file5 = pd.read_csv("bbc_news.csv")
file5
# Out:
#                                                    title  \
# 0      Ukraine: Angry Zelensky vows to punish Russian...
# 1      War in Ukraine: Taking cover in a town under a...
# 2             Ukraine war 'catastrophic for global food'
# 3      Manchester Arena bombing: Saffie Roussos's par...
# 4      Ukraine conflict: Oil price soars to highest l...
# ...                                                  ...
# 29751        Ratcliffe wants 'national stadium in north'
# 29752            Stokes bowls in nets before fourth Test
# 29753  Gauff 'fuelled' by umpire row to reach Dubai q...
# 29754  Verstappen makes ominous start to pre-season t...
# 29755  Osimhen scores on return as Napoli hold Barcelona
#
#                              pubDate  \
# 0      Mon, 07 Mar 2022 08:01:56 GMT
# 1      Sun, 06 Mar 2022 22:49:58 GMT
# 2      Mon, 07 Mar 2022 00:14:42 GMT
# 3      Mon, 07 Mar 2022 00:05:40 GMT
# 4      Mon, 07 Mar 2022 08:15:53 GMT
# ...                              ...
# ...

# %%
file1.isnull().sum()
# Out:
# Unnamed: 0         0
# title              0
# publication        0
# author          6306
# date               0
# year               0
# month              0
# url            50000
# content            0
# dtype: int64

# %%
file1["author"].fillna('Sin autor', inplace=True)
file1["url"].fillna("Sin url", inplace=True)

file1.isnull().sum()
# Out:
# Unnamed: 0     0
# title          0
# publication    0
# author         0
# date           0
# year           0
# month          0
# url            0
# content        0
# dtype: int64

# %%
file1
# Out:
#        Unnamed: 0                                              title  \
# id
# 17283           0  House Republicans Fret About Winning Their Hea...
# 17284           1  Rift Between Officers and Residents as Killing...
# 17285           2  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 17286           3  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 17287           4  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...                                                ...
# 73465       53287   Rex Tillerson Says Climate Change Is Real, but …
# 73466       53288  The Biggest Intelligence Questions Raised by t...
# 73467       53289  Trump Announces Plan That Does Little to Resol...
# 73468       53290    Dozens of For-Profit Colleges Could Soon Close
# 73469       53291                       The Milky Way’s Stolen Stars
#
#           publication                         author        date    year  \
# id
# ...

# %%
file2.isnull().sum()
# Out:
# Unnamed: 0        0
# id                0
# title             1
# publication       0
# author         8598
# date           2626
# year           2626
# month          2626
# url            7011
# content           0
# dtype: int64

# %%
file2["title"].fillna("Sin titulo", inplace = True)
file2["author"].fillna("Sin autor", inplace = True)
file2["date"].fillna("Sin fecha", inplace = True)
file2["year"].fillna("Sin año", inplace = True)
file2["month"].fillna("Sin mes", inplace = True)
file2["url"].fillna("Sin enlace", inplace = True)

file2.isnull().sum()
# Out:
# C:\Users\samcu\AppData\Local\Temp\ipykernel_19268\1629204662.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Sin año' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   file2["year"].fillna("Sin año", inplace = True)
# C:\Users\samcu\AppData\Local\Temp\ipykernel_19268\1629204662.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Sin mes' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   file2["month"].fillna("Sin mes", inplace = True)
# Unnamed: 0     0
# id             0
# title          0
# publication    0
# author         0
# date           0
# year           0
# month          0
# url            0
# content        0
# dtype: int64

# %%
file2
# Out:
#        Unnamed: 0      id                                              title  \
# 0           53293   73471  Patriots Day Is Best When It Digs Past the Her...
# 1           53294   73472  A Break in the Search for the Origin of Comple...
# 2           53295   73474         Obama’s Ingenious Mention of Atticus Finch
# 3           53296   73475         Donald Trump Meets, and Assails, the Press
# 4           53297   73476               Trump: ’I Think’ Hacking Was Russian
# ...           ...     ...                                                ...
# 49994      103453  151902  If Baltimore is serious about police reform, g...
# 49995      103454  151903  The transition from summer to fall feels like ...
# 49996      103455  151904  Colombia: Farc’s female fighters, then and now...
# 49997      103456  151905                      Why I’m optimistic about 2017
# 49998      103457  151906  Prayer and pain: why gay conversion therapy is...
#
# ...

# %%
file3.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# title            1
# publication      0
# author         972
# date            15
# year            15
# month           15
# url              0
# content          0
# dtype: int64

# %%
file3["title"].fillna("Sin titulo", inplace = True)
file3["author"].fillna("Sin autor", inplace = True)
file3["date"].fillna("Sin fecha", inplace = True)
file3["year"].fillna("Sin año", inplace = True)
file3["month"].fillna("Sin mes", inplace = True)
file3["url"].fillna("Sin enlace", inplace = True)

file3.isnull().sum()
# Out:
# Unnamed: 0     0
# id             0
# title          0
# publication    0
# author         0
# date           0
# year           0
# month          0
# url            0
# content        0
# dtype: int64

# %%
file3
# Out:
#        Unnamed: 0      id                                              title  \
# 0          103459  151908  Alton Sterling’s son: ’Everyone needs to prote...
# 1          103460  151909  Shakespeare’s first four folios sell at auctio...
# 2          103461  151910  My grandmother’s death saved me from a life of...
# 3          103462  151911  I feared my life lacked meaning. Cancer pushed...
# 4          103463  151912  Texas man serving life sentence innocent of do...
# ...           ...     ...                                                ...
# 42566      146028  218078  An eavesdropping Uber driver saved his 16-year...
# 42567      146029  218079  Plane carrying six people returning from a Cav...
# 42568      146030  218080  After helping a fraction of homeowners expecte...
# 42569      146031  218081  Yes, this is real: Michigan just banned bannin...
# 42570      146032  218082  What happened in Washington state after voters...
#
# ...

# %%
file4.isnull().sum()
# Out:
# Unnamed: 0                            0
# source_id                             0
# source_name                           0
# author                             1020
# title                                 2
# description                          24
# url                                   1
# url_to_image                        656
# published_at                          1
# content                            1292
# top_article                           2
# engagement_reaction_count           118
# engagement_comment_count            118
# engagement_share_count              118
# engagement_comment_plugin_count     118
# dtype: int64

# %%
columnas = ['engagement_reaction_count', 'engagement_comment_count', 'engagement_share_count', 'engagement_comment_plugin_count']
file4 = file4.drop(columns=columnas)
file4.isnull().sum()
# Out:
# Unnamed: 0         0
# source_id          0
# source_name        0
# author          1020
# title              2
# description       24
# url                1
# url_to_image     656
# published_at       1
# content         1292
# top_article        2
# dtype: int64

# %%
file4['author'].fillna('Sin autor', inplace=True)
file4['title'].fillna('Sin titulo', inplace=True)
file4['description'].fillna('Sin descripcion', inplace=True)
file4['url'].fillna('Sin url', inplace=True)
file4['url_to_image'].fillna('Sin enlace de imagen', inplace=True)
file4['published_at'].fillna('Sin fecha', inplace=True)
file4['content'].fillna('Sin contenido disponible', inplace=True)
file4['top_article'].fillna('Sin información', inplace=True)

file4.isnull().sum()
# Out:
# C:\Users\samcu\AppData\Local\Temp\ipykernel_19268\1553305007.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Sin información' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   file4['top_article'].fillna('Sin información', inplace=True)
# Unnamed: 0      0
# source_id       0
# source_name     0
# author          0
# title           0
# description     0
# url             0
# url_to_image    0
# published_at    0
# content         0
# top_article     0
# dtype: int64

# %%
file4
# Out:
#        Unnamed: 0           source_id         source_name  \
# 0               0             reuters             Reuters
# 1               1     the-irish-times     The Irish Times
# 2               2     the-irish-times     The Irish Times
# 3               3  al-jazeera-english  Al Jazeera English
# 4               4            bbc-news            BBC News
# ...           ...                 ...                 ...
# 10432       10432            abc-news            ABC News
# 10433       10433             reuters             Reuters
# 10434       10434                 cnn                 CNN
# 10435       10435            cbs-news            CBS News
# 10436       10436            cbs-news            CBS News
#
#                        author  \
# 0           Reuters Editorial
# 1          Eoin Burke-Kennedy
# 2           Deirdre McQuillan
# 3                  Al Jazeera
# 4                    BBC News
# ...                       ...
# 10432    The Associated Press
# ...

# %%
file5.isnull().sum()
# Out:
# title          0
# pubDate        0
# guid           0
# link           0
# description    0
# dtype: int64

# %%
file5
# Out:
#                                                    title  \
# 0      Ukraine: Angry Zelensky vows to punish Russian...
# 1      War in Ukraine: Taking cover in a town under a...
# 2             Ukraine war 'catastrophic for global food'
# 3      Manchester Arena bombing: Saffie Roussos's par...
# 4      Ukraine conflict: Oil price soars to highest l...
# ...                                                  ...
# 29751        Ratcliffe wants 'national stadium in north'
# 29752            Stokes bowls in nets before fourth Test
# 29753  Gauff 'fuelled' by umpire row to reach Dubai q...
# 29754  Verstappen makes ominous start to pre-season t...
# 29755  Osimhen scores on return as Napoli hold Barcelona
#
#                              pubDate  \
# 0      Mon, 07 Mar 2022 08:01:56 GMT
# 1      Sun, 06 Mar 2022 22:49:58 GMT
# 2      Mon, 07 Mar 2022 00:14:42 GMT
# 3      Mon, 07 Mar 2022 00:05:40 GMT
# 4      Mon, 07 Mar 2022 08:15:53 GMT
# ...                              ...
# ...

# %%
archivos = [file1, file2, file3, file4,file5]
fileJoin = pd.concat(archivos, ignore_index=True)

fileJoin
# Out:
#         Unnamed: 0                                              title  \
# 0              0.0  House Republicans Fret About Winning Their Hea...
# 1              1.0  Rift Between Officers and Residents as Killing...
# 2              2.0  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3              3.0  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4              4.0  Kim Jong-un Says North Korea Is Preparing to T...
# ...            ...                                                ...
# 182758         NaN        Ratcliffe wants 'national stadium in north'
# 182759         NaN            Stokes bowls in nets before fourth Test
# 182760         NaN  Gauff 'fuelled' by umpire row to reach Dubai q...
# 182761         NaN  Verstappen makes ominous start to pre-season t...
# 182762         NaN  Osimhen scores on return as Napoli hold Barcelona
#
#            publication                         author        date    year  \
# ...

# %%
fileJoin.isnull().sum()
# Out:
# Unnamed: 0       29756
# title                0
# publication      40193
# author           29756
# date             40193
# year             40193
# month            40193
# url              29756
# content          29756
# id               90193
# source_id       172326
# source_name     172326
# description     142570
# url_to_image    172326
# published_at    172326
# top_article     172326
# pubDate         153007
# guid            153007
# link            153007
# dtype: int64

# %%
fileJoin.dtypes
# Out:
# Unnamed: 0      float64
# title            object
# publication      object
# author           object
# date             object
# year             object
# month            object
# url              object
# content          object
# id              float64
# source_id        object
# source_name      object
# description      object
# url_to_image     object
# published_at     object
# top_article      object
# pubDate          object
# guid             object
# link             object
# dtype: object

# %%
fileJoin.to_csv('noticiasUnificado.csv', index=False)
