# %%
import pandas as pd

# %%
file = pd.read_csv("noticiasUnificado.csv")
file
# Out:
# C:\Users\samcu\AppData\Local\Temp\ipykernel_12172\3345736279.py:1: DtypeWarning: Columns (2,3,4,5,6,7,8,10,11,12,13,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv("noticiasUnificado.csv")
#         Unnamed: 0                                              title  \
# 0              0.0  House Republicans Fret About Winning Their Hea...
# 1              1.0  Rift Between Officers and Residents as Killing...
# 2              2.0  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3              3.0  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4              4.0  Kim Jong-un Says North Korea Is Preparing to T...
# ...            ...                                                ...
# 182758         NaN        Ratcliffe wants 'national stadium in north'
# 182759         NaN            Stokes bowls in nets before fourth Test
# 182760         NaN  Gauff 'fuelled' by umpire row to reach Dubai q...
# ...

# %%
file.isnull().sum()
# Out:
# Unnamed: 0       29756
# title                0
# publication      40193
# author           29756
# date             40193
# year             40193
# month            40193
# url              29756
# content          29756
# id               90193
# source_id       172326
# source_name     172326
# description     142570
# url_to_image    172326
# published_at    172326
# top_article     172326
# pubDate         153007
# guid            153007
# link            153007
# dtype: int64

# %%
file.drop('url', axis=1, inplace=True)

# %%
file.isnull().sum()
# Out:
# Unnamed: 0       29756
# title                0
# publication      40193
# author           29756
# date             40193
# year             40193
# month            40193
# content          29756
# id               90193
# source_id       172326
# source_name     172326
# description     142570
# url_to_image    172326
# published_at    172326
# top_article     172326
# pubDate         153007
# guid            153007
# link            153007
# dtype: int64

# %%
file.drop('guid', axis=1, inplace=True)
file.drop('link', axis=1, inplace=True)
file.drop('source_id', axis=1, inplace=True)
file.drop('source_name', axis=1, inplace=True)
file.drop('description', axis=1, inplace=True)
file.drop('url_to_image', axis=1, inplace=True)
file.drop('published_at', axis=1, inplace=True)
file.drop('top_article', axis=1, inplace=True)
file.drop('pubDate', axis=1, inplace=True)
# Out:
#         Unnamed: 0                                              title  \
# 182263         NaN  Crime to buses: Wellingborough by-election in ...
# 182264         NaN  Wegovy, the 'Viagra' of weight-loss drugs flyi...
# 182265         NaN  Trump on Nato: Dangerous talk at a dangerous time
# 182266         NaN  Death and Israel’s search for ‘total victory’ ...
# 182267         NaN  We couldn't afford to bury our baby, says form...
# ...            ...                                                ...
# 182758         NaN        Ratcliffe wants 'national stadium in north'
# 182759         NaN            Stokes bowls in nets before fourth Test
# 182760         NaN  Gauff 'fuelled' by umpire row to reach Dubai q...
# 182761         NaN  Verstappen makes ominous start to pre-season t...
# 182762         NaN  Osimhen scores on return as Napoli hold Barcelona
#
#        publication author date year month content  id
# 182263         NaN    NaN  NaN  NaN   NaN     NaN NaN
# ...

# %%
file.isnull().sum()
# Out:
# Unnamed: 0     29756
# title              0
# publication    40193
# author         29756
# date           40193
# year           40193
# month          40193
# content        29756
# id             90193
# dtype: int64

# %%
file.drop('id', axis=1, inplace=True)

# %%
file.isnull().sum()
# Out:
# Unnamed: 0     29756
# title              0
# publication    40193
# author         29756
# date           40193
# year           40193
# month          40193
# content        29756
# dtype: int64

# %%
file.to_csv('newsJoin.csv', index=False)
